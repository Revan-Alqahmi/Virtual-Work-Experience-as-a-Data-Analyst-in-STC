# %% [markdown]
# # STC Jawwy

# %%
"""
Here we install libraries that are not installed by default
Example:  pyslsb
Feel free to add any library you are planning to use.
"""
# !pip install pyxlsb

# %%
# Import the required libraries
"""
Please feel free to import any required libraries as per your needs
"""
import pandas as pd     # provides high-performance, easy to use structures and data analysis tools
import pyxlsb           # Excel extention to read xlsb files (the input file)
import numpy as np      # provides fast mathematical computation on arrays and matrices

# %% [markdown]
# # Jawwy dataset
# The dataset consists of details about each customer and the movies and/or tv shows watched in addition to the genre.
#
# You are required to work on task three to build a recommendation engine for our platform to Recommend movies to usesrs that they might be interested in¶

# %%
dataframe = pd.read_csv("/content/stc TV Data Set_T3.csv",index_col=0)
# Please make a copy of dataset if you are going to work directly and make changes on the dataset
df=dataframe.copy()

df.head()
# Out:
#    user_id_maped          program_name  rating                date_  \
# 0          26138            100 treets       1  2017-05-27 00:00:00
# 1           7946                 Moana       1  2017-05-21 00:00:00
# 2           7418  The Mermaid Princess       1  2017-08-10 00:00:00
# 3          19307  The Mermaid Princess       2  2017-07-26 00:00:00
# 4          15860             Churchill       2  2017-07-07 00:00:00
#
#   program_genre
# 0         Drama
# 1     Animation
# 2     Animation
# 3     Animation
# 4     Biography

# %%
# check the data shape
df.shape
# Out:
# (1048575, 5)

# %%
# display the first 5 rows
df.head()
# Out:
#    user_id_maped          program_name  rating                date_  \
# 0          26138            100 treets       1  2017-05-27 00:00:00
# 1           7946                 Moana       1  2017-05-21 00:00:00
# 2           7418  The Mermaid Princess       1  2017-08-10 00:00:00
# 3          19307  The Mermaid Princess       2  2017-07-26 00:00:00
# 4          15860             Churchill       2  2017-07-07 00:00:00
#
#   program_genre
# 0         Drama
# 1     Animation
# 2     Animation
# 3     Animation
# 4     Biography

# %%
# describe the numeric values in the dataset
df.describe()
# Out:
#        user_id_maped        rating
# count   1.048575e+06  1.048575e+06
# mean    1.709266e+04  2.497283e+00
# std     1.003513e+04  1.119837e+00
# min     1.000000e+00  1.000000e+00
# 25%     8.253000e+03  1.000000e+00
# 50%     1.714900e+04  2.000000e+00
# 75%     2.566500e+04  3.000000e+00
# max     3.428000e+04  4.000000e+00

# %%
df = df.dropna()

# %%
# check if any column has null value in the dataset
df.isnull().any()
# Out:
# user_id_maped    False
# program_name     False
# rating           False
# date_            False
# program_genre    False
# dtype: bool

# %%
df.head()
# Out:
#    user_id_maped          program_name  rating                date_  \
# 0          26138            100 treets       1  2017-05-27 00:00:00
# 1           7946                 Moana       1  2017-05-21 00:00:00
# 2           7418  The Mermaid Princess       1  2017-08-10 00:00:00
# 3          19307  The Mermaid Princess       2  2017-07-26 00:00:00
# 4          15860             Churchill       2  2017-07-07 00:00:00
#
#   program_genre
# 0         Drama
# 1     Animation
# 2     Animation
# 3     Animation
# 4     Biography

# %%
# we import Visualization libraries
# you can ignore and use any other graphing libraries
import matplotlib.pyplot as plt # a comprehensive library for creating static, animated, and interactive visualizations
import plotly #a graphing library makes interactive, publication-quality graphs. Examples of how to make line plots, scatter plots, area charts, bar charts, error bars, box plots, histograms, heatmaps, subplots, multiple-axes, polar charts, and bubble charts.
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
pip install scikit-surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163010 sha256=8017cbb796986f3ccfb63d2727734aada586b0c43fb2e344a910cc0eb86638ef
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %%
"""
TODO build your Recommender system to Highlight Programs that usesrs might be interested in
"""

# Importing necessary libraries
import pandas as pd
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
from collections import defaultdict

# Load the dataset
data = pd.read_csv("/content/stc TV Data Set_T3.csv")

# Create a Surprise Reader object
reader = Reader(rating_scale=(1, 5))

# Load data into Surprise Dataset
surprise_data = Dataset.load_from_df(data[['user_id_maped', 'program_name', 'rating']], reader)

# Split the data into train and test sets
trainset, testset = train_test_split(surprise_data, test_size=0.2)

# Build the collaborative filtering model
model = KNNBasic(sim_options={'user_based': False})  # User-based or item-based, depending on your preference

# Train the model
model.fit(trainset)

# Get recommendations for user 26138
user_id = 26138
program_ids = data['program_name'].unique()

# A dictionary to store recommendations
recommendations = defaultdict(list)

for program_id in program_ids:
    prediction = model.predict(user_id, program_id)
    recommendations[program_id] = prediction.est

# Sort recommendations by predicted rating
sorted_recommendations = sorted(recommendations.items(), key=lambda x: x[1], reverse=True)

# Print top 5 recommended programs
top_5_recommendations = sorted_recommendations[:5]
for program, rating in top_5_recommendations:
    print(f"Program: {program}, Predicted Rating: {rating}")
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Program: World's Best Chefs  Alex Atala, Predicted Rating: 4.0
# Program: Alexander and the Terrible  Horrible  No Good  Bad Day, Predicted Rating: 4.0
# Program: Bou Droosh    Ep20, Predicted Rating: 4.0
# Program: Siret Hob    Ep87, Predicted Rating: 4.0
# Program: Ash-Shak    Ep27, Predicted Rating: 4.0

# %%
"""
TODO show the recommendations (top 5) for the people who watched "Moana" movie
"""

# Importing necessary libraries
import pandas as pd
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
from collections import defaultdict

# Load the dataset
df = pd.read_csv("/content/stc TV Data Set_T3.csv")

# Filter the dataset for users who watched "Moana"
moana_users = df[df['program_name'] == 'Moana']['user_id_maped'].unique()

# Load the data into Surprise format
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id_maped', 'program_name', 'rating']], reader)

# Split the data into train and test sets
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Train the KNNBasic model
sim_options = {
    'name': 'msd',
    'user_based': True  # Use user-based collaborative filtering
}
algo = KNNBasic(sim_options=sim_options)
algo.fit(trainset)

# Dictionary to store top 5 recommendations for each user
top_n = defaultdict(list)

# Get recommendations for each user who watched "Moana"
for user in moana_users:
    # Check if the user exists in the training set
    if user in trainset._raw2inner_id_users:
        # Get top 5 recommendations for each user
        try:
            recommendations = algo.get_neighbors(trainset.to_inner_uid(user), k=5)
            top_n[user] = recommendations
        except IndexError as e:
            print(f"Error: {e}")
    else:
        print(f"User {user} not found in the training set.")

# Print the top 5 recommendations for each user
for user, recommendations in top_n.items():
    print(f"Top 5 recommendations for User {user}: {recommendations}")
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# User 16739 not found in the training set.
# User 5933 not found in the training set.
# User 13107 not found in the training set.
# User 23728 not found in the training set.
# User 14205 not found in the training set.
# User 15539 not found in the training set.
# User 18401 not found in the training set.
# User 29087 not found in the training set.
# User 25392 not found in the training set.
# User 10397 not found in the training set.
# User 20758 not found in the training set.
# User 23926 not found in the training set.
# User 8327 not found in the training set.
# User 14500 not found in the training set.
# User 33725 not found in the training set.
# Top 5 recommendations for User 7946: [28, 48, 92, 126, 194]
# Top 5 recommendations for User 26546: [28, 48, 92, 126, 194]
# Top 5 recommendations for User 20306: [28, 48, 92, 126, 194]
# Top 5 recommendations for User 28687: [3, 4, 13, 22, 23]
# ...
